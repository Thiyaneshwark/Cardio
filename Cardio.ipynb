# %%
import numpy as np
import pandas as pd
from scipy import stats as st
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import cm

# %%
df=pd.read_csv("CardioGoodFitness-1.csv")

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
num1=df["Fitness"].mean()
num1
# Out:
# 3.311111111111111

# %%
num2=df["Fitness"].median()
num2
# Out:
# 3.0

# %%
num3=df["Fitness"].mode()
num3
# Out:
# 0    3
# Name: Fitness, dtype: int64

# %%
df.sample(5)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 84    TM498   21  Female         14     Partnered      5        4   34110
# 163   TM798   28    Male         18     Partnered      7        5   77191
# 96    TM498   24  Female         16        Single      3        3   50028
# 17    TM195   23    Male         16     Partnered      4        3   39795
# 87    TM498   23    Male         14     Partnered      3        3   36384
#
#      Miles
# 84     212
# 163    180
# 96     106
# 17      94
# 87      95

# %%
df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
df.hist(figsize=(30,20))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Education'}>],
#        [<Axes: title={'center': 'Usage'}>,
#         <Axes: title={'center': 'Fitness'}>],
#        [<Axes: title={'center': 'Income'}>,
#         <Axes: title={'center': 'Miles'}>]], dtype=object)

# %%
sns.boxplot(x="Gender", y="Age", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
pd.crosstab(df['Product'],df['Gender'] )
# Out:
# Gender   Female  Male
# Product
# TM195        40    40
# TM498        29    31
# TM798         7    33

# %%
sns.countplot(x="Product", hue="Gender", data=df)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
pd.pivot_table(df,'Income', index=['Product', 'Gender'],
                     columns=[ 'MaritalStatus'])
# Out:
# MaritalStatus      Partnered        Single
# Product Gender
# TM195   Female  46153.777778  45742.384615
#         Male    50028.000000  43265.842105
# TM498   Female  49724.800000  48920.357143
#         Male    49378.285714  47071.800000
# TM798   Female  84972.250000  58516.000000
#         Male    81431.368421  68216.428571

# %%
plt.hist(x=df["Age"],color="k")
plt.title("Distribution of age")
plt.xlabel("data")
plt.ylabel("freqency")
plt.show()

# %%
plt.boxplot(x=df["Age"])
plt.title("Distribution of age")
plt.xlabel("Age")
plt.ylabel("freqency")
plt.show()

# %%
plt.boxplot([df["Age"],df["Usage"]])
plt.title("Distribution of age and usage")
plt.xlabel("Age and usage")
plt.ylabel("freqency")
plt.show()

# %%
df["Product"].value_counts().plot(kind='bar',color="pink")
plt.title("Distribution of Product")
plt.xlabel("Product")
plt.ylabel("freqency")
plt.show()

# %%
df["Product"].value_counts().plot(kind='barh',color="green")
plt.title("Distribution of Product")
plt.xlabel("Product")
plt.ylabel("freqency")
plt.show()

# %%
plt.bar("Age","Product",data=df,color="pink")
plt.title("Distribution of Age and Product")
plt.xlabel("Age")
plt.ylabel("Product")
plt.show()

# %%
Python_marks=(21,56,33,98,78)
m_marks=(23,34,67,12,98)
index=np.arange(5)
plt.bar(x=index,height=Python_marks,width=0.35,label="Python")
plt.bar(x=index+0.35, height=m_marks,width=0.35,label="m")
plt.xlabel("Student")
plt.ylabel("Scores")
plt.title("Scores by Student")
plt.xticks(ticks=index+0.35/2,labels=("A","B","C","D","E"))
plt.show()

# %%
Python_marks=(21,56,33,98,78)
m_marks=(23,34,67,12,98)
index=np.arange(5)
plt.bar(x=index,height=Python_marks,label="Python")
plt.bar(x=index, height=m_marks,label="m")
plt.xlabel("Student")
plt.ylabel("Scores")
plt.title("Scores by Student")
plt.xticks(ticks=index,labels=("A","B","C","D","E"))
plt.show()

# %%
data1=df["Product"].value_counts()
keys=data1.keys().to_list()
counts=data1.to_list()
plt.pie(x=counts,labels=keys,autopct="%1.1f%%")
plt.title("Product with Distribution")
plt.show()

# %%
data1=df["Product"].value_counts()
keys=data1.keys().to_list()
counts=data1.to_list()
explore=(1,0.1,0.5)
plt.pie(x=counts,labels=keys,autopct="%1.1f%%",explode=explore)
plt.title("Product with Distribution")
plt.show()

# %%
data1=df["Product"].value_counts()
keys=data1.keys().to_list()
counts=data1.to_list()
plt.pie(x=counts,labels=keys,autopct="%1.1f%%")
circle=plt.Circle(xy=(0,0),radius=0.3,color="white")
plt.gcf()
plt.gca().add_artist(circle)
plt.title("Product with Distribution")
plt.show()

# %%
plt.scatter(x='Age',y='Usage',data=df)
plt.title(" Scatter plot")
plt.xlabel("Age")
plt.ylabel("Usage")
plt.show()

# %%
sns.relplot(x="Fitness", y="Usage", hue = "Product", data = df);

# %%
sns.catplot(x="Usage", y="Product", data=df)

# %%
sns.catplot(x="Age", y="Product",jitter=True,data=df)

# %%
sns.catplot(x="Age", y="Product",hue="Usage",kind="swarm",data=df)

# %%
sns.catplot(x="Age", y="Product",kind="box",data=df)

# %%
sns.catplot(x="Age", y="Product",hue="Usage",kind="violin",data=df)

# %%
sns.distplot(df.Fitness, kde=False, rug = False)
# Out:
# <Axes: xlabel='Fitness'>

# %%
sns.jointplot(x=df.Age, y=df.Product,data = df)

# %%
sns.catplot(x="Age", y="Product", data=df, kind="boxen",height=4, aspect=2.7, hue = "Gender")

# %%
sns.jointplot(x="Age", y="Fitness", data=df, kind="kde");

# %%
sns.pairplot(df)

# %%
# Initialize the FacetGrid object
g = sns.FacetGrid(df, row="Fitness", hue="Fitness", aspect=5, height=3)

# # Draw the densities in a few steps
g.map(sns.kdeplot, "Age", shade=True, alpha=1, lw=3.5, bw=.2)
g.map(sns.kdeplot, "Age", color="w", lw=2, bw=.2)
g.map(plt.axhline, y=0, lw=2)

# # Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, color=color, ha="left", va="center", transform=ax.transAxes)
g.map(label, "Age")

# Set the subplots to overlap
g.fig.subplots_adjust(hspace=-.25)

# # Remove axes details that don't play well with overlap
g.set_titles("")
g.set(yticks=[])
g.despine(bottom=True, left=True)

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(corrmat, vmax=.8, square=True)
# Out:
# <Axes: >

# %%
sns.countplot(x="Gender",data=df)
plt.text(x=0.1,y=500,s=str(round(df.Gender.value_counts()[0]/len(df)*100,2))+"%")
plt.text(x=-0.9,y=320,s=str(round(df.Gender.value_counts()[0]/len(df)*100,2))+"%")
plt.title("Gender wise count Passanger")
plt.show()
